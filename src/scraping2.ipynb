# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import json

# %%
# Configuration de l'affichage pandas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# Liste des villes
cities = ["Paris", "Lyon", "Marseille", "Toulouse", "Bordeaux", "Nantes", "Nice"]

# %%
class Numbeo:
    def __init__(self):
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }

    def extract_cost_of_living(self, cities):
        """Extraction des données brutes du coût de la vie"""
        raw_data = []
        for city in cities:
            try:
                print(f"Extraction des données de coût de la vie pour {city}...")
                url = f"https://www.numbeo.com/cost-of-living/in/{city}?displayCurrency=EUR"
                response = requests.get(url, headers=self.headers)
                response.raise_for_status()
                
                soup = BeautifulSoup(response.text, 'html.parser')
                tables = soup.find_all('table', class_='data_wide_table')
                
                data = {'City': city}
                for table in tables:
                    for row in table.find_all('tr'):
                        cells = row.find_all('td')
                        if len(cells) >= 2:
                            item_name = cells[0].text.strip()
                            price_text = cells[1].text.strip()
                            data[item_name] = price_text
                
                raw_data.append(data)
                time.sleep(2)
            except Exception as e:
                print(f"Erreur extraction coût de la vie {city}: {str(e)}")
        
        # Sauvegarde des données brutes
        with open('data/extract/cost_of_living_raw.json', 'w', encoding='utf-8') as f:
            json.dump(raw_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(raw_data)
        df.to_csv('data/extract/cost_of_living_raw.csv', index=False)
        
        return raw_data

    def extract_health(self, cities):
        """Extraction des données brutes de santé"""
        raw_data = []
        for city in cities:
            try:
                print(f"Extraction des données de santé pour {city}...")
                url = f"https://www.numbeo.com/health-care/in/{city}"
                response = requests.get(url, headers=self.headers)
                response.raise_for_status()
                
                soup = BeautifulSoup(response.text, 'html.parser')
                
                data = {'City': city}
                
                # Extraction de l'index de santé général
                health_index = soup.find('td', string=re.compile('Health Care Index:'))
                if health_index and health_index.find_next_sibling():
                    data['Health Care Index'] = health_index.find_next_sibling().text.strip()
                
                # Extraction des composants de santé depuis la table
                table = soup.find('table', {'class': 'table_builder_with_value_explanation data_wide_table'})
                if table:
                    for row in table.find_all('tr')[1:]:  # Skip header row
                        cols = row.find_all('td')
                        if len(cols) >= 3:
                            component = cols[0].text.strip()
                            value = cols[2].text.strip()
                            data[component] = value
                
                raw_data.append(data)
                time.sleep(2)
                
            except Exception as e:
                print(f"Erreur extraction santé {city}: {str(e)}")
        
        # Sauvegarde des données brutes
        with open('data/extract/health_raw.json', 'w', encoding='utf-8') as f:
            json.dump(raw_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(raw_data)
        df.to_csv('data/extract/health_raw.csv', index=False)
        
        return raw_data

# %%
class DataCleaner:
    def clean_cost_of_living(self, raw_data):
        """Nettoyage des données du coût de la vie et conversion des types"""
        cleaned_data = []
        for city_data in raw_data:
            cleaned_city_data = {'City': city_data['City']}
            for key, value in city_data.items():
                if key != 'City':
                    # Nettoyer et convertir en type approprié
                    cleaned_city_data[key] = self.convert_to_numeric(self.clean_price(value))
            cleaned_data.append(cleaned_city_data)

        # Sauvegarde des données nettoyées
        with open('data/transform/cost_of_living_cleaned.json', 'w', encoding='utf-8') as f:
            json.dump(cleaned_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(cleaned_data)
        df.to_csv('data/transform/cost_of_living_cleaned.csv', index=False)
        
        return cleaned_data

    def clean_health(self, raw_data):
        """Nettoyage des données de santé et séparation des valeurs numériques"""
        cleaned_data = []
        for city_data in raw_data:
            cleaned_city_data = {'City': city_data['City']}
            for key, value in city_data.items():
                if key != 'City':
                    try:
                        # Remplacer \n par un espace et nettoyer
                        value = value.replace('\n', ' ').strip()
                        
                        # Séparer la partie numérique et textuelle
                        if value.split(' ')[0].replace('.', '').isdigit():
                            number = float(value.split(' ')[0])
                            rating = ' '.join(value.split(' ')[1:])  # Partie textuelle (High, Very High, etc.)
                            
                            # Créer deux colonnes distinctes pour la valeur numérique et le rating
                            cleaned_city_data[f"{key}_value"] = number
                            if rating:  # Si le rating existe
                                cleaned_city_data[f"{key}_rating"] = rating
                        else:
                            cleaned_city_data[key] = value
                    except (ValueError, AttributeError):
                        cleaned_city_data[key] = value

            cleaned_data.append(cleaned_city_data)

        # Sauvegarde des données nettoyées
        with open('data/transform/health_cleaned.json', 'w', encoding='utf-8') as f:
            json.dump(cleaned_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(cleaned_data)
        df.to_csv('data/transform/health_cleaned.csv', index=False)
        
        return cleaned_data

    @staticmethod
    def clean_price(price_text):
        """Nettoyage des prix - suppression des symboles d'euro"""
        try:
            price = price_text.replace(' ', '').strip()
            if '€' in price:
                price = price.replace('€', '').strip()
            price = price.replace(',', '.')
            
            if price and price.replace('.', '').isdigit():
                return price  # Retourne juste la chaîne nettoyée sans formater
            return price_text.strip().replace(' €', '')
        except:
            return price_text.strip().replace(' €', '')

    @staticmethod
    def convert_to_numeric(value_str):
        """Convertit une chaîne en un type numérique approprié (float ou int)"""
        try:
            # Tenter de convertir en float
            value_float = float(value_str)
            
            # Si c'est un entier (pas de partie décimale), convertir en int
            if value_float.is_integer():
                return int(value_float)
            else:
                return value_float
        except (ValueError, TypeError):
            # Si la conversion échoue, retourner la valeur originale
            return value_str

# %%
class DataStorage:
    def save_final_data(self, cost_data, health_data):
        """Sauvegarde des données finales"""
        # Préparation des DataFrames
        cost_df = pd.DataFrame(cost_data).set_index('City')
        health_df = pd.DataFrame(health_data).set_index('City')
        
        # Sauvegarde des données finales
        cost_df.to_csv('data/load/cost_of_living_final.csv')
        health_df.to_csv('data/load/health_final.csv')
        
        # Sauvegarde en JSON
        with open('data/load/cost_of_living_final.json', 'w', encoding='utf-8') as f:
            json.dump(cost_data, f, ensure_ascii=False, indent=4)
        
        with open('data/load/health_final.json', 'w', encoding='utf-8') as f:
            json.dump(health_data, f, ensure_ascii=False, indent=4)
        
        return cost_df, health_df

# %%
def create_directories():
    """Création des répertoires nécessaires"""
    import os
    directories = ['data/extract', 'data/transform', 'data/load']
    for directory in directories:
        os.makedirs(directory, exist_ok=True)

# %%
def main():
    # Liste des villes
    cities = ["Paris", "Lyon", "Marseille", "Toulouse", "Bordeaux", "Nantes", "Nice"]
    
    # Création des répertoires
    create_directories()
    
    # Initialisation des classes
    numbeo = Numbeo()
    cleaner = DataCleaner()
    storage = DataStorage()
    
    # 1. Extraction
    print("1. Extraction des données...")
    cost_raw_data = numbeo.extract_cost_of_living(cities)
    health_raw_data = numbeo.extract_health(cities)
    
    # 2. Transformation
    print("\n2. Nettoyage des données...")
    cost_cleaned_data = cleaner.clean_cost_of_living(cost_raw_data)
    health_cleaned_data = cleaner.clean_health(health_raw_data)
    
    # 3. Chargement
    print("\n3. Sauvegarde des données finales...")
    cost_df, health_df = storage.save_final_data(cost_cleaned_data, health_cleaned_data)
    
    print("\nAperçu des données de coût de la vie :")
    display(cost_df)
    
    print("\nAperçu des données de santé :")
    display(health_df)

if __name__ == "__main__":
    main()
# Out:
# 1. Extraction des données...
# Extraction des données de coût de la vie pour Paris...
# Extraction des données de coût de la vie pour Lyon...
# Extraction des données de coût de la vie pour Marseille...
# Extraction des données de coût de la vie pour Toulouse...
# Extraction des données de coût de la vie pour Bordeaux...
# Extraction des données de coût de la vie pour Nantes...
# Extraction des données de coût de la vie pour Nice...
# Extraction des données de santé pour Paris...
# Extraction des données de santé pour Lyon...
# Extraction des données de santé pour Marseille...
# Extraction des données de santé pour Toulouse...
# Extraction des données de santé pour Bordeaux...
# Extraction des données de santé pour Nantes...
# Extraction des données de santé pour Nice...
#
# 2. Nettoyage des données...
#
# 3. Sauvegarde des données finales...
#
# Aperçu des données de coût de la vie :
#            Meal, Inexpensive Restaurant  \
# City
# Paris                                15
# Lyon                                 15
# Marseille                            15
# Toulouse                             14
# Bordeaux                             18
# Nantes                               15
# Nice                                 20
#
#            Meal for 2 People, Mid-range Restaurant, Three-course  \
# City
# Paris                                                       65.0
# Lyon                                                        65.0
# Marseille                                                   60.0
# Toulouse                                                    60.0
# Bordeaux                                                    60.0
# Nantes                                                      57.5
# Nice                                                        75.0
#
#            McMeal at McDonalds (or Equivalent Combo Meal)  \
# City
# Paris                                                12.0
# Lyon                                                 11.0
# Marseille                                            10.0
# Toulouse                                             11.0
# Bordeaux                                             10.5
# Nantes                                               10.5
# Nice                                                 10.5
#
#            Domestic Beer (0.5 liter draught)  \
# City
# Paris                                    7.0
# Lyon                                     7.0
# Marseille                                6.0
# Toulouse                                 6.5
# Bordeaux                                 7.0
# Nantes                                   7.0
# Nice                                     7.0
#
#            Imported Beer (0.33 liter bottle)  Cappuccino (regular)  \
# City
# Paris                                   3.42                  3.87
# Lyon                                    2.45                  3.45
# Marseille                               3.50                  3.01
# Toulouse                                2.67                  2.83
# Bordeaux                                3.75                  3.50
# Nantes                                  2.83                  3.30
# Nice                                    2.50                  3.10
#
#            Coke/Pepsi (0.33 liter bottle)  Water (0.33 liter bottle)  \
# City
# Paris                                3.72                       2.94
# Lyon                                 2.62                       1.62
# Marseille                            2.60                       1.68
# Toulouse                             2.37                       1.61
# Bordeaux                             2.41                       1.34
# Nantes                               2.41                       1.25
# Nice                                 3.06                       2.31
#
#            Milk (regular), (1 liter)  Loaf of Fresh White Bread (500g)  \
# City
# Paris                           1.31                              1.90
# Lyon                            1.31                              2.41
# Marseille                       1.24                              1.92
# Toulouse                        1.25                              2.00
# Bordeaux                        1.07                              1.85
# Nantes                          1.04                              1.85
# Nice                            1.37                              1.58
#
#            Rice (white), (1kg)  Eggs (regular) (12)  Local Cheese (1kg)  \
# City
# Paris                     2.69                 4.36               22.06
# Lyon                      2.38                 3.64               21.20
# Marseille                 2.90                 3.67               22.00
# Toulouse                  2.64                 3.61               22.00
# Bordeaux                  2.75                 4.32               13.25
# Nantes                    2.71                 3.00               13.25
# Nice                      2.03                 3.93               17.83
#
#            Chicken Fillets (1kg)  \
# City
# Paris                      12.25
# Lyon                       12.94
# Marseille                  11.50
# Toulouse                   12.56
# Bordeaux                   13.42
# Nantes                     13.42
# Nice                       13.80
#
#            Beef Round (1kg) (or Equivalent Back Leg Red Meat)  Apples (1kg)  \
# City
# Paris                                                   19.49          3.12
# Lyon                                                    23.74          2.49
# Marseille                                               23.67          2.92
# Toulouse                                                15.76          2.83
# Bordeaux                                                19.60          2.88
# Nantes                                                  18.33          2.50
# Nice                                                    13.10          2.83
#
#            Banana (1kg)  Oranges (1kg)  Tomato (1kg)  Potato (1kg)  \
# City
# Paris              2.06           3.11          3.58          2.34
# Lyon               2.14           3.28          3.46          2.44
# Marseille          2.05           3.40          3.28          2.52
# Toulouse           2.68           2.80          3.06          2.37
# Bordeaux           2.00           3.36          3.95          2.08
# Nantes             1.70           2.25          2.67          1.50
# Nice               2.08           2.09          4.25          2.08
#
#            Onion (1kg)  Lettuce (1 head)  Water (1.5 liter bottle)  \
# City
# Paris             2.59              1.53                      0.75
# Lyon              2.35              1.36                      0.75
# Marseille         2.25              2.10                      1.23
# Toulouse          2.75              1.56                      0.81
# Bordeaux          2.40              1.60                      0.60
# Nantes            1.93              1.38                      0.50
# Nice              1.69              1.28                      0.61
#
#            Bottle of Wine (Mid-Range)  Domestic Beer (0.5 liter bottle)  \
# City
# Paris                             8.0                              2.27
# Lyon                              8.0                              2.34
# Marseille                         7.5                              3.62
# Toulouse                          7.0                              3.42
# Bordeaux                          9.0                              3.58
# Nantes                            6.0                              3.02
# Nice                              6.0                              1.93
#
#            Cigarettes 20 Pack (Marlboro)  One-way Ticket (Local Transport)  \
# City
# Paris                              12.50                               2.5
# Lyon                               12.00                               2.0
# Marseille                          12.00                               1.8
# Toulouse                           12.75                               1.8
# Bordeaux                           11.50                               1.8
# Nantes                             11.00                               1.8
# Nice                               11.55                               1.7
#
#            Monthly Pass (Regular Price) Taxi Start (Normal Tariff)  \
# City
# Paris                              87.0                          8
# Lyon                               72.0                        6.5
# Marseille                          40.0                          5
# Toulouse                           56.0                        2.6
# Bordeaux                           42.2                          ?
# Nantes                             57.0                          5
# Nice                               45.0                          3
#
#           Taxi 1km (Normal Tariff)  Taxi 1hour Waiting (Normal Tariff)  \
# City
# Paris                         1.96                                48.0
# Lyon                           1.8                                40.0
# Marseille                        3                                25.0
# Toulouse                       1.3                                35.2
# Bordeaux                         ?                                42.0
# Nantes                        2.48                                32.1
# Nice                          2.08                                25.8
#
#            Gasoline (1 liter)  \
# City
# Paris                    1.88
# Lyon                     1.78
# Marseille                1.83
# Toulouse                 1.77
# Bordeaux                 1.81
# Nantes                   1.77
# Nice                     1.78
#
#           Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)  \
# City
# Paris                                                       30.870.00
# Lyon                                                        32.395.00
# Marseille                                                   32.395.00
# Toulouse                                                    32.395.00
# Bordeaux                                                    32.395.00
# Nantes                                                      32.395.00
# Nice                                                        32.395.00
#
#           Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car)  \
# City
# Paris                                                          31.906.25
# Lyon                                                           32.012.50
# Marseille                                                      30.723.33
# Toulouse                                                       34.275.00
# Bordeaux                                                       30.625.00
# Nantes                                                         30.625.00
# Nice                                                           33.312.50
#
#            Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# City
# Paris                                                                        223.05
# Lyon                                                                         246.03
# Marseille                                                                    161.71
# Toulouse                                                                     164.76
# Bordeaux                                                                     219.71
# Nantes                                                                       180.32
# Nice                                                                         230.56
#
#            Mobile Phone Monthly Plan with Calls and 10GB+ Data  \
# City
# Paris                                                    15.02
# Lyon                                                     21.12
# Marseille                                                25.60
# Toulouse                                                 19.34
# Bordeaux                                                 21.23
# Nantes                                                   20.92
# Nice                                                     21.31
#
#            Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)  \
# City
# Paris                                                       32.41
# Lyon                                                        32.36
# Marseille                                                   31.11
# Toulouse                                                    31.75
# Bordeaux                                                    28.23
# Nantes                                                      23.60
# Nice                                                        33.17
#
#            Fitness Club, Monthly Fee for 1 Adult  \
# City
# Paris                                      34.14
# Lyon                                       39.36
# Marseille                                  40.00
# Toulouse                                   35.88
# Bordeaux                                   32.41
# Nantes                                     27.15
# Nice                                       30.56
#
#            Tennis Court Rent (1 Hour on Weekend)  \
# City
# Paris                                      17.68
# Lyon                                       20.00
# Marseille                                  18.60
# Toulouse                                   23.00
# Bordeaux                                   25.00
# Nantes                                     10.00
# Nice                                       21.25
#
#            Cinema, International Release, 1 Seat  \
# City
# Paris                                         13
# Lyon                                          12
# Marseille                                     13
# Toulouse                                      12
# Bordeaux                                      12
# Nantes                                        12
# Nice                                          14
#
#           Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child  \
# City
# Paris                                                                  711.11
# Lyon                                                                      560
# Marseille                                                                 705
# Toulouse                                                               741.94
# Bordeaux                                                                  729
# Nantes                                                                    729
# Nice                                                                 1.600.00
#
#           International Primary School, Yearly for 1 Child  \
# City
# Paris                                            15.500.00
# Lyon                                             10.333.33
# Marseille                                         8.625.00
# Toulouse                                         16.000.00
# Bordeaux                                          8.132.00
# Nantes                                            8.132.00
# Nice                                             17.500.00
#
#            1 Pair of Jeans (Levis 501 Or Similar)  \
# City
# Paris                                      101.59
# Lyon                                       100.43
# Marseille                                   91.67
# Toulouse                                    99.17
# Bordeaux                                    88.75
# Nantes                                      88.75
# Nice                                        95.40
#
#            1 Summer Dress in a Chain Store (Zara, H&M, ...)  \
# City
# Paris                                                 42.33
# Lyon                                                  37.83
# Marseille                                             39.83
# Toulouse                                              35.66
# Bordeaux                                              39.14
# Nantes                                                27.50
# Nice                                                  41.25
#
#            1 Pair of Nike Running Shoes (Mid-Range)  \
# City
# Paris                                        108.00
# Lyon                                         101.71
# Marseille                                     99.17
# Toulouse                                     104.14
# Bordeaux                                      85.62
# Nantes                                        82.50
# Nice                                         100.00
#
#            1 Pair of Men Leather Business Shoes  \
# City
# Paris                                    140.37
# Lyon                                     133.00
# Marseille                                124.00
# Toulouse                                 131.67
# Bordeaux                                 124.83
# Nantes                                   124.83
# Nice                                     163.00
#
#           Apartment (1 bedroom) in City Centre  \
# City
# Paris                                 1.365.64
# Lyon                                    928.69
# Marseille                                  732
# Toulouse                                748.33
# Bordeaux                                771.67
# Nantes                                  730.83
# Nice                                       926
#
#           Apartment (1 bedroom) Outside of Centre  \
# City
# Paris                                    1.018.90
# Lyon                                       643.77
# Marseille                                     600
# Toulouse                                   578.57
# Bordeaux                                   613.33
# Nantes                                     630.83
# Nice                                       796.43
#
#           Apartment (3 bedrooms) in City Centre  \
# City
# Paris                                  3.082.76
# Lyon                                   1.742.50
# Marseille                              1.287.50
# Toulouse                               1.393.75
# Bordeaux                               1.387.50
# Nantes                                 1.760.00
# Nice                                   1.883.33
#
#           Apartment (3 bedrooms) Outside of Centre  \
# City
# Paris                                     2.080.00
# Lyon                                      1.104.44
# Marseille                                 1.216.67
# Toulouse                                  1.071.43
# Bordeaux                                  1.043.75
# Nantes                                    1.266.67
# Nice                                      1.562.50
#
#           Price per Square Meter to Buy Apartment in City Centre  \
# City
# Paris                                                  12.260.87
# Lyon                                                    6.126.86
# Marseille                                               4.999.88
# Toulouse                                                4.514.67
# Bordeaux                                                5.452.88
# Nantes                                                  4.624.24
# Nice                                                    6.546.00
#
#           Price per Square Meter to Buy Apartment Outside of Centre  \
# City
# Paris                                                      8.603.45
# Lyon                                                       3.899.67
# Marseille                                                  3.128.50
# Toulouse                                                   3.118.14
# Bordeaux                                                   4.383.33
# Nantes                                                     3.382.29
# Nice                                                       3.898.17
#
#           Average Monthly Net Salary (After Tax)  \
# City
# Paris                                   3.003.00
# Lyon                                    2.601.42
# Marseille                               2.019.61
# Toulouse                                2.587.30
# Bordeaux                                2.327.67
# Nantes                                  2.113.14
# Nice                                    2.368.59
#
#            Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# City
# Paris                                                                            3.66
# Lyon                                                                             3.76
# Marseille                                                                        3.83
# Toulouse                                                                         3.71
# Bordeaux                                                                         3.79
# Nantes                                                                           3.62
# Nice                                                                             3.77
# Aperçu des données de santé :
#            Skill and competency of medical staff_value  \
# City
# Paris                                            81.75
# Lyon                                             81.06
# Marseille                                        86.76
# Toulouse                                         85.34
# Bordeaux                                         90.38
# Nantes                                           91.67
# Nice                                             89.00
#
#           Skill and competency of medical staff_rating  \
# City
# Paris                                        Very High
# Lyon                                         Very High
# Marseille                                    Very High
# Toulouse                                     Very High
# Bordeaux                                     Very High
# Nantes                                       Very High
# Nice                                         Very High
#
#            Speed in completing examinations and reports_value  \
# City
# Paris                                                   74.74
# Lyon                                                    75.00
# Marseille                                               65.62
# Toulouse                                                81.48
# Bordeaux                                                82.69
# Nantes                                                  78.33
# Nice                                                    82.00
#
#           Speed in completing examinations and reports_rating  \
# City
# Paris                                                    High
# Lyon                                                     High
# Marseille                                                High
# Toulouse                                            Very High
# Bordeaux                                            Very High
# Nantes                                                   High
# Nice                                                Very High
#
#            Equipment for modern diagnosis and treatment_value  \
# City
# Paris                                                   86.24
# Lyon                                                    86.72
# Marseille                                               88.24
# Toulouse                                                90.74
# Bordeaux                                                84.62
# Nantes                                                  86.67
# Nice                                                    91.30
#
#           Equipment for modern diagnosis and treatment_rating  \
# City
# Paris                                               Very High
# Lyon                                                Very High
# Marseille                                           Very High
# Toulouse                                            Very High
# Bordeaux                                            Very High
# Nantes                                              Very High
# Nice                                                Very High
#
#            Accuracy and completeness in filling out reports_value  \
# City
# Paris                                                       77.67
# Lyon                                                        78.33
# Marseille                                                   83.82
# Toulouse                                                    82.41
# Bordeaux                                                    84.62
# Nantes                                                      83.93
# Nice                                                        85.23
#
#           Accuracy and completeness in filling out reports_rating  \
# City
# Paris                                                        High
# Lyon                                                         High
# Marseille                                               Very High
# Toulouse                                                Very High
# Bordeaux                                                Very High
# Nantes                                                  Very High
# Nice                                                    Very High
#
#            Friendliness and courtesy of the staff_value  \
# City
# Paris                                             67.29
# Lyon                                              67.19
# Marseille                                         75.00
# Toulouse                                          82.76
# Bordeaux                                          80.77
# Nantes                                            76.67
# Nice                                              79.00
#
#           Friendliness and courtesy of the staff_rating  \
# City
# Paris                                              High
# Lyon                                               High
# Marseille                                          High
# Toulouse                                      Very High
# Bordeaux                                      Very High
# Nantes                                             High
# Nice                                               High
#
#            Satisfaction with responsiveness (waitings) in medical institutions_value  \
# City
# Paris                                                                          58.20
# Lyon                                                                           54.55
# Marseille                                                                      72.06
# Toulouse                                                                       72.32
# Bordeaux                                                                       72.92
# Nantes                                                                         58.33
# Nice                                                                           68.75
#
#           Satisfaction with responsiveness (waitings) in medical institutions_rating  \
# City
# Paris                                                                       Moderate
# Lyon                                                                        Moderate
# Marseille                                                                       High
# Toulouse                                                                        High
# Bordeaux                                                                        High
# Nantes                                                                      Moderate
# Nice                                                                            High
#
#            Satisfaction with cost to you_value  \
# City
# Paris                                    81.58
# Lyon                                     80.30
# Marseille                                91.18
# Toulouse                                 89.66
# Bordeaux                                 86.54
# Nantes                                   82.14
# Nice                                     91.67
#
#           Satisfaction with cost to you_rating  \
# City
# Paris                                Very High
# Lyon                                 Very High
# Marseille                            Very High
# Toulouse                             Very High
# Bordeaux                             Very High
# Nantes                               Very High
# Nice                                 Very High
#
#            Convenience of location for you_value  \
# City
# Paris                                      83.24
# Lyon                                       81.25
# Marseille                                  87.50
# Toulouse                                   81.25
# Bordeaux                                   88.46
# Nantes                                     75.00
# Nice                                       90.91
#
#           Convenience of location for you_rating
# City
# Paris                                  Very High
# Lyon                                   Very High
# Marseille                              Very High
# Toulouse                               Very High
# Bordeaux                               Very High
# Nantes                                      High
# Nice                                   Very High
