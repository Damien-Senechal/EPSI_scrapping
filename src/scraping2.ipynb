# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import json

# %%
# Configuration de l'affichage pandas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# Liste des villes
cities = ["Paris", "Lyon", "Marseille", "Toulouse", "Bordeaux", "Nantes", "Nice"]

# %%
class Numbeo:
    def __init__(self):
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }

    def extract_cost_of_living(self, cities):
        """Extraction des données brutes du coût de la vie"""
        raw_data = []
        for city in cities:
            try:
                print(f"Extraction des données de coût de la vie pour {city}...")
                url = f"https://www.numbeo.com/cost-of-living/in/{city}?displayCurrency=EUR"
                response = requests.get(url, headers=self.headers)
                response.raise_for_status()
                
                soup = BeautifulSoup(response.text, 'html.parser')
                tables = soup.find_all('table', class_='data_wide_table')
                
                data = {'City': city}
                for table in tables:
                    for row in table.find_all('tr'):
                        cells = row.find_all('td')
                        if len(cells) >= 2:
                            item_name = cells[0].text.strip()
                            price_text = cells[1].text.strip()
                            data[item_name] = price_text
                
                raw_data.append(data)
                time.sleep(2)
            except Exception as e:
                print(f"Erreur extraction coût de la vie {city}: {str(e)}")
        
        # Sauvegarde des données brutes
        with open('data/extract/cost_of_living_raw.json', 'w', encoding='utf-8') as f:
            json.dump(raw_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(raw_data)
        df.to_csv('data/extract/cost_of_living_raw.csv', index=False)
        
        return raw_data

    def extract_health(self, cities):
        """Extraction des données brutes de santé"""
        raw_data = []
        for city in cities:
            try:
                print(f"Extraction des données de santé pour {city}...")
                url = f"https://www.numbeo.com/health-care/in/{city}"
                response = requests.get(url, headers=self.headers)
                response.raise_for_status()
                
                soup = BeautifulSoup(response.text, 'html.parser')
                
                data = {'City': city}
                
                # Extraction de l'index de santé général
                health_index = soup.find('td', string=re.compile('Health Care Index:'))
                if health_index and health_index.find_next_sibling():
                    data['Health Care Index'] = health_index.find_next_sibling().text.strip()
                
                # Extraction des composants de santé depuis la table
                table = soup.find('table', {'class': 'table_builder_with_value_explanation data_wide_table'})
                if table:
                    for row in table.find_all('tr')[1:]:  # Skip header row
                        cols = row.find_all('td')
                        if len(cols) >= 3:
                            component = cols[0].text.strip()
                            value = cols[2].text.strip()
                            data[component] = value
                
                raw_data.append(data)
                time.sleep(2)
                
            except Exception as e:
                print(f"Erreur extraction santé {city}: {str(e)}")
        
        # Sauvegarde des données brutes
        with open('data/extract/health_raw.json', 'w', encoding='utf-8') as f:
            json.dump(raw_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(raw_data)
        df.to_csv('data/extract/health_raw.csv', index=False)
        
        return raw_data

# %%
class DataCleaner:
    def clean_cost_of_living(self, raw_data):
        """Nettoyage des données du coût de la vie"""
        cleaned_data = []
        for city_data in raw_data:
            cleaned_city_data = {'City': city_data['City']}
            for key, value in city_data.items():
                if key != 'City':
                    if "Mortgage Interest Rate" in key:
                        cleaned_city_data[key] = self.clean_price(value).replace(' €', '')
                    else:
                        cleaned_city_data[key] = self.clean_price(value)
            cleaned_data.append(cleaned_city_data)

        # Sauvegarde des données nettoyées
        with open('data/transform/cost_of_living_cleaned.json', 'w', encoding='utf-8') as f:
            json.dump(cleaned_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(cleaned_data)
        df.to_csv('data/transform/cost_of_living_cleaned.csv', index=False)
        
        return cleaned_data

    def clean_health(self, raw_data):
        """Nettoyage des données de santé"""
        cleaned_data = []
        for city_data in raw_data:
            cleaned_city_data = {'City': city_data['City']}
            for key, value in city_data.items():
                if key != 'City':
                    try:
                        # Remplacer \n par un espace et nettoyer
                        value = value.replace('\n', ' ').strip()
                        # Convertir en float et arrondir à 2 décimales
                        if value.split(' ')[0].replace('.', '').isdigit():
                            number = float(value.split(' ')[0])
                            rating = ' '.join(value.split(' ')[1:])  # Garde la partie textuelle (High, Very High, etc.)
                            cleaned_value = f"{number:.2f} {rating}"
                            cleaned_city_data[key] = cleaned_value
                        else:
                            cleaned_city_data[key] = value
                    except (ValueError, AttributeError):
                        cleaned_city_data[key] = value

            cleaned_data.append(cleaned_city_data)

        # Sauvegarde des données nettoyées
        with open('data/transform/health_cleaned.json', 'w', encoding='utf-8') as f:
            json.dump(cleaned_data, f, ensure_ascii=False, indent=4)
        
        df = pd.DataFrame(cleaned_data)
        df.to_csv('data/transform/health_cleaned.csv', index=False)
        
        return cleaned_data

    @staticmethod
    def clean_price(price_text):
        """Nettoyage des prix"""
        try:
            price = price_text.replace(' ', '').strip()
            if '€' in price:
                price = price.replace('€', '').strip()
            price = price.replace(',', '.')
            
            if price and price.replace('.', '').isdigit():
                value = float(price)
                return f"{value:.2f} €"
            return price_text.strip()
        except:
            return price_text.strip()

# %%
class DataStorage:
    def save_final_data(self, cost_data, health_data):
        """Sauvegarde des données finales"""
        # Préparation des DataFrames
        cost_df = pd.DataFrame(cost_data).set_index('City')
        health_df = pd.DataFrame(health_data).set_index('City')
        
        # Sauvegarde des données finales
        cost_df.to_csv('data/load/cost_of_living_final.csv')
        health_df.to_csv('data/load/health_final.csv')
        
        # Sauvegarde en JSON
        with open('data/load/cost_of_living_final.json', 'w', encoding='utf-8') as f:
            json.dump(cost_data, f, ensure_ascii=False, indent=4)
        
        with open('data/load/health_final.json', 'w', encoding='utf-8') as f:
            json.dump(health_data, f, ensure_ascii=False, indent=4)
        
        return cost_df, health_df

# %%
def create_directories():
    """Création des répertoires nécessaires"""
    import os
    directories = ['data/extract', 'data/transform', 'data/load']
    for directory in directories:
        os.makedirs(directory, exist_ok=True)

# %%
def main():
    # Liste des villes
    cities = ["Paris", "Lyon", "Marseille", "Toulouse", "Bordeaux", "Nantes", "Nice"]
    
    # Création des répertoires
    create_directories()
    
    # Initialisation des classes
    numbeo = Numbeo()
    cleaner = DataCleaner()
    storage = DataStorage()
    
    # 1. Extraction
    print("1. Extraction des données...")
    cost_raw_data = numbeo.extract_cost_of_living(cities)
    health_raw_data = numbeo.extract_health(cities)
    
    # 2. Transformation
    print("\n2. Nettoyage des données...")
    cost_cleaned_data = cleaner.clean_cost_of_living(cost_raw_data)
    health_cleaned_data = cleaner.clean_health(health_raw_data)
    
    # 3. Chargement
    print("\n3. Sauvegarde des données finales...")
    cost_df, health_df = storage.save_final_data(cost_cleaned_data, health_cleaned_data)
    
    print("\nAperçu des données de coût de la vie :")
    display(cost_df)
    
    print("\nAperçu des données de santé :")
    display(health_df)

if __name__ == "__main__":
    main()
# Out:
# 1. Extraction des données...
# Extraction des données de coût de la vie pour Paris...
# Extraction des données de coût de la vie pour Lyon...
# Extraction des données de coût de la vie pour Marseille...
# Extraction des données de coût de la vie pour Toulouse...
# Extraction des données de coût de la vie pour Bordeaux...
# Extraction des données de coût de la vie pour Nantes...
# Extraction des données de coût de la vie pour Nice...
# Extraction des données de santé pour Paris...
# Extraction des données de santé pour Lyon...
# Extraction des données de santé pour Marseille...
# Extraction des données de santé pour Toulouse...
# Extraction des données de santé pour Bordeaux...
# Extraction des données de santé pour Nantes...
# Extraction des données de santé pour Nice...
#
# 2. Nettoyage des données...
#
# 3. Sauvegarde des données finales...
#
# Aperçu des données de coût de la vie :
#           Meal, Inexpensive Restaurant  \
# City
# Paris                          15.00 €
# Lyon                           15.00 €
# Marseille                      15.00 €
# Toulouse                       14.50 €
# Bordeaux                       17.50 €
# Nantes                         15.00 €
# Nice                           20.00 €
#
#           Meal for 2 People, Mid-range Restaurant, Three-course  \
# City
# Paris                                                   70.00 €
# Lyon                                                    70.00 €
# Marseille                                               62.50 €
# Toulouse                                                60.00 €
# Bordeaux                                                60.00 €
# Nantes                                                  55.00 €
# Nice                                                    80.00 €
#
#           McMeal at McDonalds (or Equivalent Combo Meal)  \
# City
# Paris                                            12.00 €
# Lyon                                             11.00 €
# Marseille                                        10.00 €
# Toulouse                                         11.00 €
# Bordeaux                                         10.00 €
# Nantes                                           10.00 €
# Nice                                             10.50 €
#
#           Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# City
# Paris                                7.00 €                            3.43 €
# Lyon                                 7.00 €                            2.45 €
# Marseille                            6.85 €                            2.45 €
# Toulouse                             6.75 €                            3.00 €
# Bordeaux                             7.50 €                            3.75 €
# Nantes                               7.00 €                            2.83 €
# Nice                                 7.00 €                            2.20 €
#
#           Cappuccino (regular) Coke/Pepsi (0.33 liter bottle)  \
# City
# Paris                   3.91 €                         3.88 €
# Lyon                    3.41 €                         2.87 €
# Marseille               3.14 €                         2.60 €
# Toulouse                2.88 €                         2.42 €
# Bordeaux                3.50 €                         2.41 €
# Nantes                  3.06 €                         2.30 €
# Nice                    3.09 €                         3.04 €
#
#           Water (0.33 liter bottle) Milk (regular), (1 liter)  \
# City
# Paris                        2.92 €                    1.33 €
# Lyon                         1.64 €                    1.35 €
# Marseille                    1.61 €                    1.19 €
# Toulouse                     1.56 €                    1.27 €
# Bordeaux                     1.34 €                    1.08 €
# Nantes                       1.30 €                    1.01 €
# Nice                         2.29 €                    1.41 €
#
#           Loaf of Fresh White Bread (500g) Rice (white), (1kg)  \
# City
# Paris                               1.95 €              2.62 €
# Lyon                                2.38 €              2.31 €
# Marseille                           2.12 €              2.31 €
# Toulouse                            2.00 €              2.64 €
# Bordeaux                            1.85 €              2.65 €
# Nantes                              1.85 €              2.65 €
# Nice                                1.58 €              2.28 €
#
#           Eggs (regular) (12) Local Cheese (1kg) Chicken Fillets (1kg)  \
# City
# Paris                  4.41 €            21.25 €               12.56 €
# Lyon                   3.75 €            21.20 €               13.28 €
# Marseille              3.44 €            21.20 €               11.80 €
# Toulouse               3.61 €            22.00 €               12.56 €
# Bordeaux               4.47 €            13.25 €               13.42 €
# Nantes                 3.30 €            13.25 €               13.42 €
# Nice                   4.10 €            20.29 €               14.00 €
#
#           Beef Round (1kg) (or Equivalent Back Leg Red Meat) Apples (1kg)  \
# City
# Paris                                                19.80 €       3.21 €
# Lyon                                                 21.38 €       2.49 €
# Marseille                                            21.38 €       2.49 €
# Toulouse                                             15.76 €       2.83 €
# Bordeaux                                             18.25 €       2.85 €
# Nantes                                               18.25 €       2.85 €
# Nice                                                 12.63 €       2.51 €
#
#           Banana (1kg) Oranges (1kg) Tomato (1kg) Potato (1kg) Onion (1kg)  \
# City
# Paris           2.12 €        3.17 €       3.60 €       2.35 €      2.61 €
# Lyon            2.03 €        3.47 €       3.46 €       2.38 €      2.35 €
# Marseille       2.03 €        3.25 €       3.46 €       2.38 €      1.92 €
# Toulouse        2.68 €        2.80 €       3.06 €       2.37 €      2.30 €
# Bordeaux        2.00 €        3.50 €       3.84 €       2.20 €      2.28 €
# Nantes          1.62 €        2.00 €       3.00 €       1.50 €      1.77 €
# Nice            1.78 €        2.11 €       4.67 €       2.08 €      1.69 €
#
#           Lettuce (1 head) Water (1.5 liter bottle)  \
# City
# Paris               1.56 €                   0.74 €
# Lyon                1.36 €                   0.75 €
# Marseille           1.36 €                   0.75 €
# Toulouse            1.56 €                   0.81 €
# Bordeaux            1.67 €                   0.66 €
# Nantes              1.25 €                   0.50 €
# Nice                1.18 €                   0.53 €
#
#           Bottle of Wine (Mid-Range) Domestic Beer (0.5 liter bottle)  \
# City
# Paris                         8.00 €                           2.23 €
# Lyon                          8.00 €                           2.34 €
# Marseille                     6.75 €                           2.34 €
# Toulouse                      7.00 €                           3.42 €
# Bordeaux                      9.00 €                           3.58 €
# Nantes                        6.00 €                           3.02 €
# Nice                          7.00 €                           2.37 €
#
#           Cigarettes 20 Pack (Marlboro) One-way Ticket (Local Transport)  \
# City
# Paris                           12.50 €                           2.15 €
# Lyon                            11.75 €                           2.00 €
# Marseille                       11.75 €                           1.80 €
# Toulouse                        12.75 €                           1.90 €
# Bordeaux                        11.00 €                           1.80 €
# Nantes                          11.00 €                           1.80 €
# Nice                            11.50 €                           1.70 €
#
#           Monthly Pass (Regular Price) Taxi Start (Normal Tariff)  \
# City
# Paris                          86.40 €                     8.00 €
# Lyon                           70.00 €                     5.00 €
# Marseille                      48.00 €                     5.00 €
# Toulouse                       56.00 €                     2.60 €
# Bordeaux                       42.85 €                     2.00 €
# Nantes                         58.50 €                     3.50 €
# Nice                           40.00 €                     3.00 €
#
#           Taxi 1km (Normal Tariff) Taxi 1hour Waiting (Normal Tariff)  \
# City
# Paris                       2.00 €                            50.00 €
# Lyon                        1.80 €                            40.00 €
# Marseille                   3.00 €                            26.50 €
# Toulouse                    1.30 €                            35.20 €
# Bordeaux                    1.66 €                            39.00 €
# Nantes                      2.48 €                            32.10 €
# Nice                        2.08 €                            25.80 €
#
#           Gasoline (1 liter)  \
# City
# Paris                 1.89 €
# Lyon                  1.79 €
# Marseille             1.79 €
# Toulouse              1.77 €
# Bordeaux              1.81 €
# Nantes                1.77 €
# Nice                  1.77 €
#
#           Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)  \
# City
# Paris                                                     30,870.00 €
# Lyon                                                      32,395.00 €
# Marseille                                                 32,395.00 €
# Toulouse                                                  32,395.00 €
# Bordeaux                                                  32,395.00 €
# Nantes                                                    32,395.00 €
# Nice                                                      32,395.00 €
#
#           Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car)  \
# City
# Paris                                                        32,331.25 €
# Lyon                                                         32,012.50 €
# Marseille                                                    30,868.00 €
# Toulouse                                                     32,812.50 €
# Bordeaux                                                     32,812.50 €
# Nantes                                                       31,062.50 €
# Nice                                                         33,312.50 €
#
#           Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# City
# Paris                                                                     236.21 €
# Lyon                                                                      228.92 €
# Marseille                                                                 166.42 €
# Toulouse                                                                  163.63 €
# Bordeaux                                                                  219.71 €
# Nantes                                                                    172.78 €
# Nice                                                                      222.19 €
#
#           Mobile Phone Monthly Plan with Calls and 10GB+ Data  \
# City
# Paris                                                 15.14 €
# Lyon                                                  21.71 €
# Marseille                                             21.71 €
# Toulouse                                              19.34 €
# Bordeaux                                              21.81 €
# Nantes                                                21.81 €
# Nice                                                  21.67 €
#
#           Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)  \
# City
# Paris                                                    31.84 €
# Lyon                                                     32.54 €
# Marseille                                                29.44 €
# Toulouse                                                 30.85 €
# Bordeaux                                                 28.92 €
# Nantes                                                   23.60 €
# Nice                                                     33.42 €
#
#           Fitness Club, Monthly Fee for 1 Adult  \
# City
# Paris                                   33.80 €
# Lyon                                    38.80 €
# Marseille                               37.00 €
# Toulouse                                35.88 €
# Bordeaux                                32.72 €
# Nantes                                  27.15 €
# Nice                                    30.56 €
#
#           Tennis Court Rent (1 Hour on Weekend)  \
# City
# Paris                                   16.93 €
# Lyon                                    20.00 €
# Marseille                               19.50 €
# Toulouse                                23.00 €
# Bordeaux                                25.00 €
# Nantes                                  10.00 €
# Nice                                    21.25 €
#
#           Cinema, International Release, 1 Seat  \
# City
# Paris                                   13.00 €
# Lyon                                    11.00 €
# Marseille                               11.00 €
# Toulouse                                12.50 €
# Bordeaux                                12.00 €
# Nantes                                  12.00 €
# Nice                                    14.00 €
#
#           Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child  \
# City
# Paris                                                                730.62 €
# Lyon                                                                 560.00 €
# Marseille                                                            560.00 €
# Toulouse                                                             753.55 €
# Bordeaux                                                             664.50 €
# Nantes                                                               664.50 €
# Nice                                                               1,600.00 €
#
#           International Primary School, Yearly for 1 Child  \
# City
# Paris                                          14,857.14 €
# Lyon                                           10,333.33 €
# Marseille                                       8,833.33 €
# Toulouse                                       16,000.00 €
# Bordeaux                                        5,800.00 €
# Nantes                                          5,800.00 €
# Nice                                           17,500.00 €
#
#           1 Pair of Jeans (Levis 501 Or Similar)  \
# City
# Paris                                   100.11 €
# Lyon                                     89.67 €
# Marseille                                89.67 €
# Toulouse                                100.00 €
# Bordeaux                                 91.25 €
# Nantes                                   91.25 €
# Nice                                     93.75 €
#
#           1 Summer Dress in a Chain Store (Zara, H&M, ...)  \
# City
# Paris                                              42.50 €
# Lyon                                               37.83 €
# Marseille                                          37.00 €
# Toulouse                                           39.00 €
# Bordeaux                                           37.33 €
# Nantes                                             28.75 €
# Nice                                               41.25 €
#
#           1 Pair of Nike Running Shoes (Mid-Range)  \
# City
# Paris                                     102.59 €
# Lyon                                       87.00 €
# Marseille                                  87.00 €
# Toulouse                                  103.62 €
# Bordeaux                                   80.00 €
# Nantes                                     80.00 €
# Nice                                      100.00 €
#
#           1 Pair of Men Leather Business Shoes  \
# City
# Paris                                 138.20 €
# Lyon                                  133.00 €
# Marseille                             133.00 €
# Toulouse                              133.33 €
# Bordeaux                              119.80 €
# Nantes                                119.80 €
# Nice                                  163.00 €
#
#           Apartment (1 bedroom) in City Centre  \
# City
# Paris                               1,339.49 €
# Lyon                                  904.54 €
# Marseille                             762.18 €
# Toulouse                              748.33 €
# Bordeaux                              767.50 €
# Nantes                                677.00 €
# Nice                                  969.17 €
#
#           Apartment (1 bedroom) Outside of Centre  \
# City
# Paris                                  1,011.18 €
# Lyon                                     630.75 €
# Marseille                                615.00 €
# Toulouse                                 578.57 €
# Bordeaux                                 600.83 €
# Nantes                                   589.17 €
# Nice                                     846.15 €
#
#           Apartment (3 bedrooms) in City Centre  \
# City
# Paris                                3,050.00 €
# Lyon                                 1,815.83 €
# Marseille                            1,338.33 €
# Toulouse                             1,491.67 €
# Bordeaux                             1,438.89 €
# Nantes                               1,575.00 €
# Nice                                 1,875.00 €
#
#           Apartment (3 bedrooms) Outside of Centre  \
# City
# Paris                                   2,061.54 €
# Lyon                                    1,118.75 €
# Marseille                               1,178.00 €
# Toulouse                                1,050.00 €
# Bordeaux                                1,094.44 €
# Nantes                                  1,220.00 €
# Nice                                    1,716.67 €
#
#           Price per Square Meter to Buy Apartment in City Centre  \
# City
# Paris                                                12,052.54 €
# Lyon                                                  6,048.00 €
# Marseille                                             5,168.62 €
# Toulouse                                              4,341.25 €
# Bordeaux                                              5,403.83 €
# Nantes                                                4,624.24 €
# Nice                                                  6,878.43 €
#
#           Price per Square Meter to Buy Apartment Outside of Centre  \
# City
# Paris                                                    8,590.00 €
# Lyon                                                     3,899.67 €
# Marseille                                                3,078.50 €
# Toulouse                                                 3,078.38 €
# Bordeaux                                                 4,375.00 €
# Nantes                                                   3,382.29 €
# Nice                                                     3,898.17 €
#
#           Average Monthly Net Salary (After Tax)  \
# City
# Paris                                 2,992.52 €
# Lyon                                  2,591.38 €
# Marseille                             2,001.74 €
# Toulouse                              2,587.30 €
# Bordeaux                              2,351.00 €
# Nantes                                2,182.00 €
# Nice                                  2,484.62 €
#
#           Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# City
# Paris                                                                           3.72
# Lyon                                                                            3.76
# Marseille                                                                       3.84
# Toulouse                                                                        3.71
# Bordeaux                                                                        3.79
# Nantes                                                                          3.62
# Nice                                                                            3.77
# Aperçu des données de santé :
#           Skill and competency of medical staff  \
# City
# Paris                           82.49 Very High
# Lyon                            81.06 Very High
# Marseille                       86.76 Very High
# Toulouse                        80.65 Very High
# Bordeaux                        90.38 Very High
# Nantes                          91.67 Very High
# Nice                            89.00 Very High
#
#           Speed in completing examinations and reports  \
# City
# Paris                                       75.40 High
# Lyon                                        75.00 High
# Marseille                                   65.62 High
# Toulouse                                    75.86 High
# Bordeaux                               82.69 Very High
# Nantes                                      78.33 High
# Nice                                   82.00 Very High
#
#           Equipment for modern diagnosis and treatment  \
# City
# Paris                                  87.17 Very High
# Lyon                                   86.72 Very High
# Marseille                              88.24 Very High
# Toulouse                               87.93 Very High
# Bordeaux                               84.62 Very High
# Nantes                                 86.67 Very High
# Nice                                   91.30 Very High
#
#           Accuracy and completeness in filling out reports  \
# City
# Paris                                           78.38 High
# Lyon                                            78.33 High
# Marseille                                  83.82 Very High
# Toulouse                                        76.72 High
# Bordeaux                                   84.62 Very High
# Nantes                                     83.93 Very High
# Nice                                       85.23 Very High
#
#           Friendliness and courtesy of the staff  \
# City
# Paris                                 67.61 High
# Lyon                                  67.19 High
# Marseille                             75.00 High
# Toulouse                              77.42 High
# Bordeaux                         80.77 Very High
# Nantes                                76.67 High
# Nice                                  79.00 High
#
#           Satisfaction with responsiveness (waitings) in medical institutions  \
# City
# Paris                                                          58.83 Moderate
# Lyon                                                           54.55 Moderate
# Marseille                                                          72.06 High
# Toulouse                                                           67.50 High
# Bordeaux                                                           72.92 High
# Nantes                                                         58.33 Moderate
# Nice                                                               68.75 High
#
#           Satisfaction with cost to you Convenience of location for you
# City
# Paris                   82.18 Very High                 84.14 Very High
# Lyon                    80.30 Very High                 81.25 Very High
# Marseille               91.18 Very High                 87.50 Very High
# Toulouse                83.87 Very High                      75.83 High
# Bordeaux                86.54 Very High                 88.46 Very High
# Nantes                  82.14 Very High                      75.00 High
# Nice                    91.67 Very High                 90.91 Very High
